# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # Segment Videos with Segment Anything 2 (SAM2)
#
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/facebookresearch/segment-anything-2)
#
# Segment Anything Model 2 (SAM 2) is a foundation model designed to address promptable visual segmentation in both images and videos. The model extends its functionality to video by treating images as single-frame videos. Its design, a simple transformer architecture with streaming memory, enables real-time video processing. A model-in-the-loop data engine, which enhances the model and data through user interaction, was built to collect the SA-V dataset, the largest video segmentation dataset to date. SAM 2, trained on this extensive dataset, delivers robust performance across diverse tasks and visual domains.
#
# ![segment anything model](https://media.roboflow.com/notebooks/examples/segment-anything-model-2-paper.jpg)
#
# This notebook is an extension of the official [notebook](https://github.com/facebookresearch/segment-anything-2/blob/main/notebooks/video_predictor_example.ipynb) prepared by Meta AI.
#
# ## Complementary materials
#
# ---
#
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-segment-videos-with-sam-2.ipynb)
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/what-is-segment-anything-2)
#
# We recommend that you follow along in this notebook while reading the blog post on Segment Anything Model 2 (SAM2).
#
# [![SAM2 blogpost](https://media.roboflow.com/notebooks/examples/blog-what-is-sam-2.png)](https://blog.roboflow.com/what-is-segment-anything-2)

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Tue Oct 29 12:46:30 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8              13W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print("HOME:", HOME)
# Out:
# HOME: /content

# %% [markdown]
# ### Install SAM2 and dependencies

# %%
# !git clone https://github.com/facebookresearch/segment-anything-2.git
# %cd {HOME}/segment-anything-2
# !pip install -e . -q
# !python setup.py build_ext --inplace
# Out:
# Cloning into 'segment-anything-2'...
# remote: Enumerating objects: 974, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 974 (delta 17), reused 21 (delta 7), pack-reused 936 (from 1)
# Receiving objects: 100% (974/974), 128.94 MiB | 13.22 MiB/s, done.
# Resolving deltas: 100% (334/334), done.
# /content/segment-anything-2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.2 MB/s eta 0:00:00
#   Building editable for SAM-2 (pyproject.toml) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for iopath (setup.py) ... done
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:497: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'sam2._C' extension
# creating build/temp.linux-x86_64-cpython-310/sam2/csrc
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c sam2/csrc/connected_components.cu -o build/temp.linux-x86_64-cpython-310/sam2/csrc/connected_components.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -DCUDA_HAS_FP16=1 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75 -std=c++17
# creating build/lib.linux-x86_64-cpython-310/sam2
# x86_64-linux-gnu-g++ -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions build/temp.linux-x86_64-cpython-310/sam2/csrc/connected_components.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-310/sam2/_C.so
# copying build/lib.linux-x86_64-cpython-310/sam2/_C.so -> sam2

# %%
# !pip install -q supervision[assets] jupyter_bbox_widget
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.7/213.7 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 47.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.5 MB/s eta 0:00:00

# %% [markdown]
# ### Download SAM2 checkpoints
#
# **NOTE:** SAM2 is available in 4 different model sizes ranging from the lightweight "sam2_hiera_tiny" (38.9M parameters) to the more powerful "sam2_hiera_large" (224.4M parameters).

# %%
# !mkdir -p {HOME}/checkpoints
# !wget -q https://dl.fbaipublicfiles.com/segment_anything_2/072824/sam2_hiera_tiny.pt -P {HOME}/checkpoints
# !wget -q https://dl.fbaipublicfiles.com/segment_anything_2/072824/sam2_hiera_small.pt -P {HOME}/checkpoints
# !wget -q https://dl.fbaipublicfiles.com/segment_anything_2/072824/sam2_hiera_base_plus.pt -P {HOME}/checkpoints
# !wget -q https://dl.fbaipublicfiles.com/segment_anything_2/072824/sam2_hiera_large.pt -P {HOME}/checkpoints

# %% [markdown]
# ### Imports

# %%
import cv2
import torch
import base64

import numpy as np
import supervision as sv

from pathlib import Path
from supervision.assets import download_assets, VideoAssets
from sam2.build_sam import build_sam2_video_predictor

IS_COLAB = True

if IS_COLAB:
    from google.colab import output
    output.enable_custom_widget_manager()

from jupyter_bbox_widget import BBoxWidget

# %% [markdown]
# **NOTE:** This code enables mixed-precision computing for faster deep learning. It uses bfloat16 for most calculations and, on newer NVIDIA GPUs, leverages TensorFloat-32 (TF32) for certain operations to further boost performance.

# %%
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

if torch.cuda.get_device_properties(0).major >= 8:
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True

# %% [markdown]
# ## Load model

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
CHECKPOINT = f"{HOME}/checkpoints/sam2_hiera_large.pt"
CONFIG = "sam2_hiera_l.yaml"

sam2_model = build_sam2_video_predictor(CONFIG, CHECKPOINT)
# Out:
# UserWarning: Flash Attention is disabled as it requires a GPU with Ampere (8.0) CUDA capability.

# %% [markdown]
# ## Preprocess video

# %% [markdown]
# ### Download video and split it into frames
#
# **NOTE:** SAM2 assumee that the video is stored as a list of JPEG frames with filenames like `<frame_index>.jpg`. Let's start by downloading a sample video, splitting it into frames, and saving them to disk. Feel free to replace `SOURCE_VIDEO` with the path to your video file.

# %%
SOURCE_VIDEO = '/content/tong.mp4'
sv.VideoInfo.from_video_path(SOURCE_VIDEO)
# Out:
# VideoInfo(width=640, height=480, fps=5, total_frames=213)

# %% [markdown]
# **NOTE:** To reduce VRAM requirements, we are introducing three additional parameters: `SCALE_FACTOR` to decrease the frame resolution, and `START_IDX` and `END_IDX` to extract only the relevant segments from the video.

# %%
SCALE_FACTOR = 1
START_IDX = 0
END_IDX = 213

# %%
SOURCE_FRAMES = Path(HOME) / Path(SOURCE_VIDEO).stem
SOURCE_FRAMES.mkdir(parents=True, exist_ok=True)

frames_generator = sv.get_video_frames_generator(SOURCE_VIDEO, start=START_IDX, end=END_IDX)
images_sink = sv.ImageSink(
    target_dir_path=SOURCE_FRAMES.as_posix(),
    overwrite=True,
    image_name_pattern="{:05d}.jpeg"
)

with images_sink:
    for frame in frames_generator:
        frame = sv.scale_image(frame, SCALE_FACTOR)
        images_sink.save_image(frame)

TARGET_VIDEO = Path(HOME) / f"{Path(SOURCE_VIDEO).stem}-result.mp4"
SOURCE_FRAME_PATHS = sorted(sv.list_files_with_extensions(SOURCE_FRAMES.as_posix(), extensions=["jpeg"]))

# %% [markdown]
# ### Initialize the inference state
#
# **NOTE:** SAM 2 requires stateful inference for interactive video segmentation, so we need to initialize an inference state on this video. During initialization, it loads all the JPEG frames in `video_path` and stores their pixels in `inference_state` (as shown in the progress bar below).

# %%
inference_state = sam2_model.init_state(video_path=SOURCE_FRAMES.as_posix())
# Out:
# frame loading (JPEG): 100%|██████████| 213/213 [00:06<00:00, 32.10it/s]

# %% [markdown]
# **NOTE:** If you have run any previous tracking using this inference_state, please reset it first via reset_state. (The cell below is just for illustration; it's not needed to call reset_state here as this inference_state is just freshly initialized above.)

# %%
sam2_model.reset_state(inference_state)

# %% [markdown]
# ### Prompting with points

# %%
def encode_image(filepath):
    with open(filepath, 'rb') as f:
        image_bytes = f.read()
    encoded = str(base64.b64encode(image_bytes), 'utf-8')
    return "data:image/jpg;base64,"+encoded

# %% [markdown]
# **NOTE:** SAM2 allows tracking multiple objects at once. Update the `OBJECTS` list if you want to change the list of tracked objects.

# %%
OBJECTS = ['ball', 'player-1', 'player-2']

# %% [markdown]
# **NOTE:** Let's choose the index of the reference frame that we will use to annotate the objects we are looking for.

# %%
FRAME_IDX = 0
FRAME_PATH = Path(SOURCE_FRAMES) / f"{FRAME_IDX:05d}.jpeg"

widget = BBoxWidget(classes=OBJECTS)
widget.image = encode_image(FRAME_PATH)
widget
# Out:
# BBoxWidget(classes=['ball', 'player-1', 'player-2'], colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#946…

# %% [markdown]
# **NOTE:** The widget we are using stores annotations in a format that is inconsistent with SAM2's requirements. We parse them and then pass them to SAM2 via the `add_new_points` method. Each of the objects we track must be passed via a separate `add_new_points` call. It is important to specify `frame_idx` each time - the index of the frame to which the annotations relate, and `obj_id` - the ID of the object to which the annotations relate.

# %%
default_box = [
    {'x': 705, 'y': 302, 'width': 0, 'height': 0, 'label': 'ball'},
    {'x': 587, 'y': 300, 'width': 0, 'height': 0, 'label': 'player-1'},
    {'x': 753, 'y': 267, 'width': 0, 'height': 0, 'label': 'player-2'}
]

boxes = widget.bboxes if widget.bboxes else default_box

for object_id, label in enumerate(OBJECTS, start=1):
    boxes = [box for box in widget.bboxes if box['label'] == label]

    if len(boxes) == 0:
        continue

    points = np.array([
        [
            box['x'],
            box['y']
        ] for box in boxes
    ], dtype=np.float32)
    labels = np.ones(len(points))

    _, object_ids, mask_logits = sam2_model.add_new_points(
        inference_state=inference_state,
        frame_idx=FRAME_IDX,
        obj_id=object_id,
        points=points,
        labels=labels,
    )

# %% [markdown]
# ### Video inference
#
# **NOTE:** To apply our point prompts to all video frames, we use the `propagate_in_video` generator. Each call returns `frame_idx` - the index of the current frame, `object_ids` - IDs of objects detected in the frame, and `mask_logits` - corresponding `object_ids` logit values, which we can convert to masks using thresholding.

# %%
video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO)
video_info.width = int(video_info.width * SCALE_FACTOR)
video_info.height = int(video_info.height * SCALE_FACTOR)

COLORS = ['#FF1493', '#00BFFF', '#FF6347', '#FFD700']
mask_annotator = sv.MaskAnnotator(
    color=sv.ColorPalette.from_hex(COLORS),
    color_lookup=sv.ColorLookup.CLASS)

frame_sample = []
import os
import cv2
#os.mkdir('/content/tong_mask')
with sv.VideoSink(TARGET_VIDEO.as_posix(), video_info=video_info) as sink:
    for frame_idx, object_ids, mask_logits in sam2_model.propagate_in_video(inference_state):
        frame_path = SOURCE_FRAME_PATHS[frame_idx]
        frame = cv2.imread(frame_path)
        masks = (mask_logits > 0.0).cpu().numpy()
        masks = np.squeeze(masks).astype(bool)
        mask = masks.astype(np.int8)*255

        cv2.imwrite('/content/tong_mask/mask_{}.png'.format(frame_idx), mask)
# Out:
# propagate in video: 100%|██████████| 213/213 [04:14<00:00,  1.20s/it]

# %%
 # !zip -r /content/file.zip /content/tong_mask
# Out:
#   adding: content/tong_mask/ (stored 0%)
#   adding: content/tong_mask/mask_1.png (deflated 64%)
#   adding: content/tong_mask/mask_102.png (deflated 65%)
#   adding: content/tong_mask/mask_76.png (deflated 53%)
#   adding: content/tong_mask/mask_88.png (deflated 58%)
#   adding: content/tong_mask/mask_203.png (deflated 74%)
#   adding: content/tong_mask/mask_151.png (deflated 49%)
#   adding: content/tong_mask/mask_11.png (deflated 58%)
#   adding: content/tong_mask/mask_121.png (deflated 43%)
#   adding: content/tong_mask/mask_206.png (deflated 76%)
#   adding: content/tong_mask/mask_65.png (deflated 48%)
#   adding: content/tong_mask/mask_13.png (deflated 60%)
#   adding: content/tong_mask/mask_51.png (deflated 51%)
#   adding: content/tong_mask/mask_89.png (deflated 67%)
#   adding: content/tong_mask/mask_25.png (deflated 56%)
#   adding: content/tong_mask/mask_173.png (deflated 75%)
#   adding: content/tong_mask/mask_99.png (deflated 65%)
#   adding: content/tong_mask/mask_170.png (deflated 72%)
#   adding: content/tong_mask/mask_63.png (deflated 47%)
#   adding: content/tong_mask/mask_177.png (deflated 73%)
#   adding: content/tong_mask/mask_112.png (deflated 54%)
#   adding: content/tong_mask/mask_142.png (deflated 56%)
#   adding: content/tong_mask/mask_93.png (deflated 65%)
#   adding: content/tong_mask/mask_155.png (deflated 43%)
#   adding: content/tong_mask/mask_42.png (deflated 53%)
#   adding: content/tong_mask/mask_59.png (deflated 52%)
#   adding: content/tong_mask/mask_187.png (deflated 80%)
#   adding: content/tong_mask/mask_104.png (deflated 68%)
#   adding: content/tong_mask/mask_28.png (deflated 55%)
#   adding: content/tong_mask/mask_182.png (deflated 80%)
#   adding: content/tong_mask/mask_35.png (deflated 47%)
#   adding: content/tong_mask/mask_3.png (deflated 64%)
#   adding: content/tong_mask/mask_153.png (deflated 45%)
#   adding: content/tong_mask/mask_16.png (deflated 58%)
#   adding: content/tong_mask/mask_86.png (deflated 50%)
#   adding: content/tong_mask/mask_130.png (deflated 45%)
#   adding: content/tong_mask/mask_37.png (deflated 43%)
#   adding: content/tong_mask/mask_119.png (deflated 41%)
#   adding: content/tong_mask/mask_137.png (deflated 55%)
#   adding: content/tong_mask/mask_154.png (deflated 42%)
#   adding: content/tong_mask/mask_61.png (deflated 57%)
#   adding: content/tong_mask/mask_158.png (deflated 45%)
#   adding: content/tong_mask/mask_135.png (deflated 47%)
#   adding: content/tong_mask/mask_77.png (deflated 49%)
#   adding: content/tong_mask/mask_101.png (deflated 64%)
#   adding: content/tong_mask/mask_82.png (deflated 55%)
#   adding: content/tong_mask/mask_55.png (deflated 53%)
#   adding: content/tong_mask/mask_12.png (deflated 59%)
#   adding: content/tong_mask/mask_14.png (deflated 63%)
#   adding: content/tong_mask/mask_189.png (deflated 78%)
#   adding: content/tong_mask/mask_175.png (deflated 70%)
#   adding: content/tong_mask/mask_67.png (deflated 49%)
#   adding: content/tong_mask/mask_171.png (deflated 70%)
#   adding: content/tong_mask/mask_164.png (deflated 73%)
#   adding: content/tong_mask/mask_91.png (deflated 64%)
#   adding: content/tong_mask/mask_146.png (deflated 54%)
#   adding: content/tong_mask/mask_127.png (deflated 45%)
#   adding: content/tong_mask/mask_71.png (deflated 50%)
#   adding: content/tong_mask/mask_58.png (deflated 55%)
#   adding: content/tong_mask/mask_141.png (deflated 54%)
#   adding: content/tong_mask/mask_105.png (deflated 66%)
#   adding: content/tong_mask/mask_24.png (deflated 58%)
#   adding: content/tong_mask/mask_169.png (deflated 69%)
#   adding: content/tong_mask/mask_205.png (deflated 78%)
#   adding: content/tong_mask/mask_31.png (deflated 67%)
#   adding: content/tong_mask/mask_96.png (deflated 60%)
#   adding: content/tong_mask/mask_40.png (deflated 46%)
#   adding: content/tong_mask/mask_0.png (deflated 63%)
#   adding: content/tong_mask/mask_199.png (deflated 92%)
#   adding: content/tong_mask/mask_197.png (deflated 76%)
#   adding: content/tong_mask/mask_133.png (deflated 47%)
#   adding: content/tong_mask/mask_33.png (deflated 46%)
#   adding: content/tong_mask/mask_84.png (deflated 57%)
#   adding: content/tong_mask/mask_150.png (deflated 47%)
#   adding: content/tong_mask/mask_176.png (deflated 72%)
#   adding: content/tong_mask/mask_21.png (deflated 54%)
#   adding: content/tong_mask/mask_122.png (deflated 48%)
#   adding: content/tong_mask/mask_70.png (deflated 50%)
#   adding: content/tong_mask/mask_57.png (deflated 51%)
#   adding: content/tong_mask/mask_62.png (deflated 52%)
#   adding: content/tong_mask/mask_166.png (deflated 68%)
#   adding: content/tong_mask/mask_128.png (deflated 52%)
#   adding: content/tong_mask/mask_210.png (deflated 79%)
#   adding: content/tong_mask/mask_44.png (deflated 48%)
#   adding: content/tong_mask/mask_68.png (deflated 48%)
#   adding: content/tong_mask/mask_75.png (deflated 52%)
#   adding: content/tong_mask/mask_64.png (deflated 50%)
#   adding: content/tong_mask/mask_186.png (deflated 78%)
#   adding: content/tong_mask/mask_208.png (deflated 75%)
#   adding: content/tong_mask/mask_113.png (deflated 57%)
#   adding: content/tong_mask/mask_100.png (deflated 70%)
#   adding: content/tong_mask/mask_47.png (deflated 42%)
#   adding: content/tong_mask/mask_56.png (deflated 49%)
#   adding: content/tong_mask/mask_198.png (deflated 92%)
#   adding: content/tong_mask/mask_162.png (deflated 60%)
#   adding: content/tong_mask/mask_179.png (deflated 79%)
#   adding: content/tong_mask/mask_131.png (deflated 49%)
#   adding: content/tong_mask/mask_72.png (deflated 47%)
#   adding: content/tong_mask/mask_126.png (deflated 57%)
#   adding: content/tong_mask/mask_54.png (deflated 51%)
#   adding: content/tong_mask/mask_120.png (deflated 44%)
#   adding: content/tong_mask/mask_201.png (deflated 83%)
#   adding: content/tong_mask/mask_69.png (deflated 52%)
#   adding: content/tong_mask/mask_60.png (deflated 53%)
#   adding: content/tong_mask/mask_116.png (deflated 51%)
#   adding: content/tong_mask/mask_188.png (deflated 74%)
#   adding: content/tong_mask/mask_147.png (deflated 60%)
#   adding: content/tong_mask/mask_97.png (deflated 69%)
#   adding: content/tong_mask/mask_156.png (deflated 38%)
#   adding: content/tong_mask/mask_180.png (deflated 82%)
#   adding: content/tong_mask/mask_94.png (deflated 65%)
#   adding: content/tong_mask/mask_32.png (deflated 63%)
#   adding: content/tong_mask/mask_144.png (deflated 52%)
#   adding: content/tong_mask/mask_107.png (deflated 61%)
#   adding: content/tong_mask/mask_209.png (deflated 76%)
#   adding: content/tong_mask/mask_148.png (deflated 50%)
#   adding: content/tong_mask/mask_9.png (deflated 54%)
#   adding: content/tong_mask/mask_10.png (deflated 65%)
#   adding: content/tong_mask/mask_117.png (deflated 55%)
#   adding: content/tong_mask/mask_207.png (deflated 73%)
#   adding: content/tong_mask/mask_53.png (deflated 44%)
#   adding: content/tong_mask/mask_48.png (deflated 41%)
#   adding: content/tong_mask/mask_49.png (deflated 42%)
#   adding: content/tong_mask/mask_43.png (deflated 48%)
#   adding: content/tong_mask/mask_125.png (deflated 59%)
#   adding: content/tong_mask/mask_17.png (deflated 58%)
#   adding: content/tong_mask/mask_174.png (deflated 73%)
#   adding: content/tong_mask/mask_66.png (deflated 48%)
#   adding: content/tong_mask/mask_92.png (deflated 64%)
#   adding: content/tong_mask/mask_167.png (deflated 66%)
#   adding: content/tong_mask/mask_160.png (deflated 60%)
#   adding: content/tong_mask/mask_145.png (deflated 52%)
#   adding: content/tong_mask/mask_81.png (deflated 52%)
#   adding: content/tong_mask/mask_110.png (deflated 63%)
#   adding: content/tong_mask/mask_18.png (deflated 60%)
#   adding: content/tong_mask/mask_115.png (deflated 56%)
#   adding: content/tong_mask/mask_149.png (deflated 51%)
#   adding: content/tong_mask/mask_184.png (deflated 82%)
#   adding: content/tong_mask/mask_19.png (deflated 73%)
#   adding: content/tong_mask/mask_8.png (deflated 64%)
#   adding: content/tong_mask/mask_183.png (deflated 75%)
#   adding: content/tong_mask/mask_194.png (deflated 74%)
#   adding: content/tong_mask/mask_211.png (deflated 81%)
#   adding: content/tong_mask/mask_204.png (deflated 74%)
#   adding: content/tong_mask/mask_192.png (deflated 79%)
#   adding: content/tong_mask/mask_138.png (deflated 62%)
#   adding: content/tong_mask/mask_181.png (deflated 73%)
#   adding: content/tong_mask/mask_74.png (deflated 46%)
#   adding: content/tong_mask/mask_159.png (deflated 49%)
#   adding: content/tong_mask/mask_27.png (deflated 57%)
#   adding: content/tong_mask/mask_202.png (deflated 74%)
#   adding: content/tong_mask/mask_95.png (deflated 64%)
#   adding: content/tong_mask/mask_108.png (deflated 62%)
#   adding: content/tong_mask/mask_190.png (deflated 75%)
#   adding: content/tong_mask/mask_90.png (deflated 58%)
#   adding: content/tong_mask/mask_195.png (deflated 73%)
#   adding: content/tong_mask/mask_36.png (deflated 46%)
#   adding: content/tong_mask/mask_7.png (deflated 57%)
#   adding: content/tong_mask/mask_185.png (deflated 77%)
#   adding: content/tong_mask/mask_34.png (deflated 45%)
#   adding: content/tong_mask/mask_73.png (deflated 51%)
#   adding: content/tong_mask/mask_83.png (deflated 51%)
#   adding: content/tong_mask/mask_46.png (deflated 41%)
#   adding: content/tong_mask/mask_26.png (deflated 59%)
#   adding: content/tong_mask/mask_193.png (deflated 75%)
#   adding: content/tong_mask/mask_124.png (deflated 44%)
#   adding: content/tong_mask/mask_114.png (deflated 62%)
#   adding: content/tong_mask/mask_103.png (deflated 66%)
#   adding: content/tong_mask/mask_5.png (deflated 62%)
#   adding: content/tong_mask/mask_87.png (deflated 58%)
#   adding: content/tong_mask/mask_109.png (deflated 68%)
#   adding: content/tong_mask/mask_191.png (deflated 77%)
#   adding: content/tong_mask/mask_98.png (deflated 72%)
#   adding: content/tong_mask/mask_163.png (deflated 56%)
#   adding: content/tong_mask/mask_106.png (deflated 65%)
#   adding: content/tong_mask/mask_6.png (deflated 66%)
#   adding: content/tong_mask/mask_212.png (deflated 77%)
#   adding: content/tong_mask/mask_172.png (deflated 71%)
#   adding: content/tong_mask/mask_38.png (deflated 50%)
#   adding: content/tong_mask/mask_78.png (deflated 47%)
#   adding: content/tong_mask/mask_196.png (deflated 73%)
#   adding: content/tong_mask/mask_118.png (deflated 48%)
#   adding: content/tong_mask/mask_134.png (deflated 43%)
#   adding: content/tong_mask/mask_80.png (deflated 49%)
#   adding: content/tong_mask/mask_161.png (deflated 60%)
#   adding: content/tong_mask/mask_152.png (deflated 45%)
#   adding: content/tong_mask/mask_2.png (deflated 62%)
#   adding: content/tong_mask/mask_123.png (deflated 43%)
#   adding: content/tong_mask/mask_4.png (deflated 61%)
#   adding: content/tong_mask/mask_15.png (deflated 59%)
#   adding: content/tong_mask/mask_41.png (deflated 49%)
#   adding: content/tong_mask/mask_111.png (deflated 53%)
#   adding: content/tong_mask/mask_136.png (deflated 55%)
#   adding: content/tong_mask/mask_165.png (deflated 68%)
#   adding: content/tong_mask/mask_79.png (deflated 50%)
#   adding: content/tong_mask/mask_52.png (deflated 43%)
#   adding: content/tong_mask/mask_143.png (deflated 56%)
#   adding: content/tong_mask/mask_132.png (deflated 45%)
#   adding: content/tong_mask/mask_129.png (deflated 48%)
#   adding: content/tong_mask/mask_50.png (deflated 43%)
#   adding: content/tong_mask/mask_23.png (deflated 72%)
#   adding: content/tong_mask/mask_168.png (deflated 69%)
#   adding: content/tong_mask/mask_29.png (deflated 60%)
#   adding: content/tong_mask/mask_39.png (deflated 44%)
#   adding: content/tong_mask/mask_200.png (deflated 81%)
#   adding: content/tong_mask/mask_140.png (deflated 53%)
#   adding: content/tong_mask/mask_45.png (deflated 47%)
#   adding: content/tong_mask/mask_30.png (deflated 63%)
#   adding: content/tong_mask/mask_139.png (deflated 47%)
#   adding: content/tong_mask/mask_22.png (deflated 54%)
#   adding: content/tong_mask/mask_178.png (deflated 74%)
#   adding: content/tong_mask/mask_20.png (deflated 64%)
#   adding: content/tong_mask/mask_85.png (deflated 51%)
#   adding: content/tong_mask/mask_157.png (deflated 42%)
